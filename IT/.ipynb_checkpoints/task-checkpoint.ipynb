# %%
import os
import math
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Getting data

# %%
train = pd.read_csv(r'C:\Programs\MyPrograms\Python\ML\3K2SML\IT\train.csv').dropna()
test = pd.read_csv(r'C:\Programs\MyPrograms\Python\ML\3K2SML\IT\train.csv').dropna()

# %% [markdown]
# Correlation between features

# %%
corr = train.corr()
sns.heatmap(corr)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Correlation between features and target variable

# %%
target = 'TotalTimeStopped_p50'
corr_with_target = train.corrwith(train[target])
print(corr_with_target)
# Out:
# RowId                     -0.079955
# IntersectionId            -0.052091
# Latitude                  -0.040408
# Longitude                 -0.015290
# Hour                       0.044358
# Weekend                   -0.092669
# Month                     -0.007770
# TotalTimeStopped_p20       0.705616
# TotalTimeStopped_p40       0.935787
# TotalTimeStopped_p50       1.000000
# TotalTimeStopped_p60       0.926398
# TotalTimeStopped_p80       0.798863
# TimeFromFirstStop_p20      0.705584
# TimeFromFirstStop_p40      0.897283
# TimeFromFirstStop_p50      0.936334
# TimeFromFirstStop_p60      0.861883
# TimeFromFirstStop_p80      0.752047
# DistanceToFirstStop_p20    0.511409
# DistanceToFirstStop_p40    0.561816
# DistanceToFirstStop_p50    0.551528
# DistanceToFirstStop_p60    0.478650
# DistanceToFirstStop_p80    0.394077
# dtype: float64

# %% [markdown]
# Scatter plots: feature vs. feature, feature vs. target

# %%
features = list(train)[12::2]
sns.pairplot(train[::500][features])
plt.tight_layout()
plt.show()

# %%
features = list(train)[12:]
target = 'TotalTimeStopped_p50'
sns.pairplot(train[::500][features], y_vars=target)
plt.tight_layout()
plt.show()

# %% [markdown]
# Bar charts for features

# %%
fig, axes = plt.subplots(1, 3, sharey=True, figsize=(45,10))
fig.suptitle('Total time stopped dependance', fontsize='20')

sns.barplot(data=train[::1000], x='Hour', y='TotalTimeStopped_p50', ax=axes[0])
sns.barplot(data=train[::1000], x='Weekend', y='TotalTimeStopped_p50', ax=axes[1])
sns.barplot(data=train[::1000], x='Month', y='TotalTimeStopped_p50', ax=axes[2])
# Out:
# <AxesSubplot:xlabel='Month', ylabel='TotalTimeStopped_p50'>

# %% [markdown]
# Custom linear regressor

# %%
def normalize(X):
    mean = X.mean(axis=0)
    std = X.std(axis=0)
    X_new = (X - mean)/std
    return X_new, mean, std

# %%
def prepare_X(X):
    m = X.shape[0]
    ones = np.ones((m, 1))
    X_new = np.array(X[:])
    X_new = np.column_stack((ones, X_new))
    return X_new

# %%
def hypothesis(X, theta):
    h_theta = np.sum(X*theta, axis=1)
    return h_theta

# %%
def cost_function(X, y, theta):
    m = X.shape[0]
    if m == 0:
        return None
    J = 1/(2*m)*sum((hypothesis(X, theta) - y)**2)
    return

# %%
def derivative(X, y, theta):
    m = X.shape[0]
    d_theta = 1/m*np.sum(X*((hypothesis(X, theta) - y)**2)[:,np.newaxis], axis=0)
    return d_theta

# %%
def gradient_descent(X, y, theta, alpha, num_iters, print_J = True):
    m = X.shape[0]
    J_history = []
    J = cost_function(X, y, theta)
    if print_J == True:
        print(J)
    J_history.append(J)
    for i in range(num_iters):
        delta = derivative(X, y, theta)
        theta = theta - alpha*delta
        J = cost_function(X, y, theta)
        if print_J == True:
            print(J)
        J_history.append(J)
    return theta, J_history

# %%
X_train, y_train = train[['Hour', 'Weekend', 'Month']].to_numpy(), train['TotalTimeStopped_p50'].to_numpy()
X_test, y_test = test[['Hour', 'Weekend', 'Month']].to_numpy(), test['TotalTimeStopped_p50'].to_numpy()

# %%
X_train_normalized, mean, std = normalize(X_train) 
print(X_train_normalized)
# Out:
# (842452, 3)
# (3,)
# (3,)
# (842452, 3)
# [[-2.04514547 -0.62190143 -1.55887906]
#  [-2.04514547 -0.62190143 -1.55887906]
#  [-1.88061755 -0.62190143 -1.55887906]
#  ...
#  [ 1.08088505  1.60797185  1.45433168]
#  [ 1.24541297  1.60797185  1.45433168]
#  [ 1.73899674  1.60797185  1.45433168]]
